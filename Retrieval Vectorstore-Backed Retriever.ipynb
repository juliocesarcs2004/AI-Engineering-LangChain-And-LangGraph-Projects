# %% [markdown]
# # Retrieval: Vectorstore-Backed Retriever (LangChain 1.2.x)

# %%
# %load_ext dotenv
# %dotenv

# %%
from langchain_openai.embeddings import OpenAIEmbeddings
from langchain_chroma import Chroma
from langchain_core.documents import Document

# %%
embedding = OpenAIEmbeddings()

vectorstore = Chroma(persist_directory = "./intro-to-ds-lectures", 
                     embedding_function = embedding)

# %%
len(vectorstore.get()['documents'])
# Out:
# 81

# %%
retriever = vectorstore.as_retriever(search_type = 'mmr',
                                     search_kwargs = {'k': 3,
                                                      'lambda_mult': 0.7})

# %%
retriever
# Out:
# VectorStoreRetriever(tags=['Chroma', 'OpenAIEmbeddings'], vectorstore=<langchain_chroma.vectorstores.Chroma object at 0x10d3d1e40>, search_type='mmr', search_kwargs={'k': 3, 'lambda_mult': 0.7})

# %%
question = "What software do data scientists use?"

# %%
retrieved_docs = retriever.invoke(question)

# %%
retrieved_docs
# Out:
# [Document(id='f57a2d28-fbf0-4636-8a19-bf809e9a523f', metadata={'Course Title': 'Introduction to Data and Data Science', 'Lecture Title': 'Programming Languages & Software Employed in Data Science - All the Tools You Need'}, page_content='As you can see from the infographic, R, and Python are the two most popular tools across all columns. Their biggest advantage is that they can manipulate data and are integrated within multiple data and data science software platforms. They are not just suitable for mathematical and statistical computations. In other words, R, and Python are adaptable. They can solve a wide variety of business and data-related problems from beginning to the end'),
#  Document(id='ec0a58ee-309a-4ee8-9738-6ad05b6caed1', metadata={'Lecture Title': 'Programming Languages & Software Employed in Data Science - All the Tools You Need', 'Course Title': 'Introduction to Data and Data Science'}, page_content='Alright! So… How are the techniques used in data, business intelligence, or predictive analytics applied in real life? Certainly, with the help of computers. You can basically split the relevant tools into two categories—programming languages and software. Knowing a programming language enables you to devise programs that can execute specific operations. Moreover, you can reuse these programs whenever you need to execute the same action'),
#  Document(id='5db75bc5-469b-474a-ba82-1abf007dd5ac', metadata={'Course Title': 'Introduction to Data and Data Science', 'Lecture Title': 'Programming Languages & Software Employed in Data Science - All the Tools You Need'}, page_content='It’s actually a software framework which was designed to address the complexity of big data and its computational intensity. Most notably, Hadoop distributes the computational tasks on multiple computers which is basically the way to handle big data nowadays. Power BI, SaS, Qlik, and especially Tableau are top-notch examples of software designed for business intelligence visualizations')]

# %%
for i in retrieved_docs:
    print(f"Page Content: {i.page_content}\n----------\nLecture Title:{i.metadata['Lecture Title']}\n")
# Out:
# Page Content: As you can see from the infographic, R, and Python are the two most popular tools across all columns. Their biggest advantage is that they can manipulate data and are integrated within multiple data and data science software platforms. They are not just suitable for mathematical and statistical computations. In other words, R, and Python are adaptable. They can solve a wide variety of business and data-related problems from beginning to the end
# ----------
# Lecture Title:Programming Languages & Software Employed in Data Science - All the Tools You Need
#
# Page Content: Alright! So… How are the techniques used in data, business intelligence, or predictive analytics applied in real life? Certainly, with the help of computers. You can basically split the relevant tools into two categories—programming languages and software. Knowing a programming language enables you to devise programs that can execute specific operations. Moreover, you can reuse these programs whenever you need to execute the same action
# ----------
# Lecture Title:Programming Languages & Software Employed in Data Science - All the Tools You Need
#
# Page Content: It’s actually a software framework which was designed to address the complexity of big data and its computational intensity. Most notably, Hadoop distributes the computational tasks on multiple computers which is basically the way to handle big data nowadays. Power BI, SaS, Qlik, and especially Tableau are top-notch examples of software designed for business intelligence visualizations
# ----------
# Lecture Title:Programming Languages & Software Employed in Data Science - All the Tools You Need
