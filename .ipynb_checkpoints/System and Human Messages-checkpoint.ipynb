# %% [markdown]
# ## ChatOpenAI

# %%
# %load_ext dotenv
# %dotenv
# Out:
# The dotenv extension is already loaded. To reload it, use:
#   %reload_ext dotenv

# %%
from langchain_openai.chat_models import ChatOpenAI

# %%
chat = ChatOpenAI(model_name = 'gpt-4',
                  seed = 365,
                  temperature = 0,
                  max_tokens = 100)

# %%
response = chat.invoke(''' I've recently adopted a dog. Could you suggest some dog names? ''')

# %%
response
# Out:
# AIMessage(content='Of course! Here are some suggestions:\n\nMale Dog Names:\n1. Max\n2. Charlie\n3. Cooper\n4. Buddy\n5. Jack\n6. Rocky\n7. Duke\n8. Bear\n9. Zeus\n10. Toby\n\nFemale Dog Names:\n1. Bella\n2. Lucy\n3. Daisy\n4. Luna\n5. Lola\n6. Sadie\n7. Molly\n8. Bailey\n9. Stella\n10. Maggie\n\nUnisex Dog', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 100, 'prompt_tokens': 22, 'total_tokens': 122, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4-0613', 'system_fingerprint': None, 'id': 'chatcmpl-CnTxzAfna49GnA8YC0f5ZqkOk2hpr', 'service_tier': 'default', 'finish_reason': 'length', 'logprobs': None}, id='lc_run--019b2865-7941-7151-bba6-19070e5c1ef5-0', usage_metadata={'input_tokens': 22, 'output_tokens': 100, 'total_tokens': 122, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
print(response.content)
# Out:
# Of course! Here are some suggestions:
#
# Male Dog Names:
# 1. Max
# 2. Charlie
# 3. Cooper
# 4. Buddy
# 5. Jack
# 6. Rocky
# 7. Duke
# 8. Bear
# 9. Zeus
# 10. Toby
#
# Female Dog Names:
# 1. Bella
# 2. Lucy
# 3. Daisy
# 4. Luna
# 5. Lola
# 6. Sadie
# 7. Molly
# 8. Bailey
# 9. Stella
# 10. Maggie
#
# Unisex Dog Names:
# 1. Harley
# 2. Riley
# 3. Casey
# 4. Frankie
# 5. Sam
# 6. Alex
# 7. Jordan
# 8. Taylor
# 9. Jamie
# 10. Charlie
#
# Remember, the best name for your dog is one that fits their personality and makes you happy!
