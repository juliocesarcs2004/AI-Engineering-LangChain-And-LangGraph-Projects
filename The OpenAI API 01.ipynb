# %% [markdown]
# ## First Steps

# %%
# %load_ext dotenv
# %dotenv
# Out:
# The dotenv extension is already loaded. To reload it, use:
#   %reload_ext dotenv

# %%
import os
import openai

# %%
openai.api_key = os.getenv('OPENAI_API_KEY')

# %%
client = openai.OpenAI()

# %%
completion = client.chat.completions.create(model = 'gpt-4',
                                            messages = [{'role':'user',
                                                         'content':''' I've recently adopted a dog.
                                                         Could you explain briefly what a black hole is?'''}],
                                           max_tokens= 250,
                                           temperature = 0,
                                           seed = 365,
                                           stream = True)

# %%
completion

# %%
for i in completion:
    print(i.choices[0].delta.content, end = "")
# Out:
# A black hole is a region in space where the pulling force of gravity is so strong that light is not able to escape. The strong gravity occurs because matter has been pressed into a tiny space. This compression can take place at the end of a star's life. Some black holes are a result of dying stars. Because no light can escape, black holes are invisible. However, space telescopes with special tools can help find black holes. They can observe the behavior of stars and gases close to black holes.None
